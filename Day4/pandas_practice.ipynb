# %%
import pandas as pd

# %% [markdown]
# # Problem 1

# %%
dataset = pd.read_csv("student_performance.csv")

# %% [markdown]
# # Problem 2

# %%
dataset.head()
# Out:
#   Student_ID         Name  Age Program  Python  Mathematics  Statistics  \
# 0       S001     Ali Khan   20      AI      85           78          92
# 1       S002   Sara Ahmed   21      AI      72           75          70
# 2       S003   Ahmed Raza   22      SE      90           88          91
# 3       S004  Fatima Noor   20      DS      65           70          68
# 4       S005    Usman Ali   21      AI      78           82          80
#
#    Machine_Learning  Attendance
# 0                88          95
# 1                80          90
# 2                93          96
# 3                72          85
# 4                76          88

# %%
dataset.tail()
# Out:
#    Student_ID         Name  Age Program  Python  Mathematics  Statistics  \
# 15       S016    Hira Shah   21      DS      89           91          88
# 16       S017  Omar Farooq   20      AI      74           72          76
# 17       S018   Laiba Khan   22      SE      97           95          98
# 18       S019     Abdullah   21      DS      68           66          70
# 19       S020      Mehwish   20      AI      86           89          87
#
#     Machine_Learning  Attendance
# 15                90          96
# 16                78          84
# 17                99         100
# 18                72          80
# 19                90          93

# %% [markdown]
# # Problem 3

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student_ID        20 non-null     str
#  1   Name              20 non-null     str
#  2   Age               20 non-null     int64
#  3   Program           20 non-null     str
#  4   Python            20 non-null     int64
#  5   Mathematics       20 non-null     int64
#  6   Statistics        20 non-null     int64
#  7   Machine_Learning  20 non-null     int64
#  8   Attendance        20 non-null     int64
# dtypes: int64(6), str(3)
# memory usage: 1.5 KB

# %% [markdown]
# # Probelm 4 - finding missing values

# %%
dataset.isna()
# Out:
#     Student_ID   Name    Age  Program  Python  Mathematics  Statistics  \
# 0        False  False  False    False   False        False       False
# 1        False  False  False    False   False        False       False
# 2        False  False  False    False   False        False       False
# 3        False  False  False    False   False        False       False
# 4        False  False  False    False   False        False       False
# 5        False  False  False    False   False        False       False
# 6        False  False  False    False   False        False       False
# 7        False  False  False    False   False        False       False
# 8        False  False  False    False   False        False       False
# 9        False  False  False    False   False        False       False
# 10       False  False  False    False   False        False       False
# 11       False  False  False    False   False        False       False
# ...

# %%
dataset.isna().sum() # missing values count in each column
# Out:
# Student_ID          0
# Name                0
# Age                 0
# Program             0
# Python              0
# Mathematics         0
# Statistics          0
# Machine_Learning    0
# Attendance          0
# dtype: int64

# %% [markdown]
# # Problem 5

# %%
# filtering based on condition
# attendace > 90
dataset = dataset.loc[dataset['Attendance'] > 90]

# %%
dataset
# Out:
#    Student_ID          Name  Age Program  Python  Mathematics  Statistics  \
# 0        S001      Ali Khan   20      AI      85           78          92
# 2        S003    Ahmed Raza   22      SE      90           88          91
# 5        S006  Ayesha Malik   22      SE      95           94          96
# 7        S008  Zainab Iqbal   21      AI      88           86          90
# 9        S010   Maryam Khan   20      DS      81           84          79
# 11       S012   Noor Fatima   21      SE      92           90          93
# 13       S014    Iqra Aslam   22      AI      84           83          86
# 15       S016     Hira Shah   21      DS      89           91          88
# 17       S018    Laiba Khan   22      SE      97           95          98
# 19       S020       Mehwish   20      AI      86           89          87
#
#     Machine_Learning  Attendance
# 0                 88          95
# 2                 93          96
# 5                 97          99
# ...

# %% [markdown]
# # Problem 6

# %%
# summary statistics of new filtered dataset 
dataset.describe()
# Out:
#              Age    Python  Mathematics  Statistics  Machine_Learning  \
# count  10.000000  10.00000    10.000000   10.000000         10.000000
# mean   21.100000  88.70000    87.800000   90.000000         91.600000
# std     0.875595   4.98999     5.202563    5.416026          4.376706
# min    20.000000  81.00000    78.000000   79.000000         85.000000
# 25%    20.250000  85.25000    84.500000   87.250000         88.500000
# 50%    21.000000  88.50000    88.500000   90.500000         90.500000
# 75%    22.000000  91.50000    90.750000   92.750000         94.500000
# max    22.000000  97.00000    95.000000   98.000000         99.000000
#
#        Attendance
# count   10.000000
# mean    95.400000
# std      2.988868
# min     91.000000
# 25%     93.250000
# 50%     95.500000
# 75%     97.500000
# max    100.000000
